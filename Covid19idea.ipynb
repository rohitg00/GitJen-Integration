# %%
# !pip install xlrd
import folium
import pandas as pd
# Out:
# Collecting xlrd
#   Downloading xlrd-1.2.0-py2.py3-none-any.whl (103 kB)
# Installing collected packages: xlrd
# Successfully installed xlrd-1.2.0

# %%
dataset = pd.read_excel('waterwatch_clean2.xlsx')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 8 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Unnamed: 0                                      121 non-null    int64
#  1   Suburb                                          121 non-null    object
#  2   Number of single-residential properties_number  121 non-null    int64
#  3   Oct 2017
# kl/month                               121 non-null    int64
#  4   Month                                           121 non-null    object
#  5   Year                                            121 non-null    int64
#  6   Latitude                                        121 non-null    float64
#  7   Longitude                                       121 non-null    float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 7.7+ KB

# %%
dataset.columns
# Out:
# Index(['Unnamed: 0', 'Suburb',
#        'Number of single-residential properties_number', 'Oct 2017\nkl/month',
#        'Month', 'Year', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
dataset.head(10)
# Out:
#    Unnamed: 0           Suburb  \
# 0           0          ATHLONE
# 1           1           AURORA
# 2           2       BANTRY BAY
# 3           3  BELLVILLE SOUTH
# 4           4        BERGVLIET
# 5           5     BISHOP LAVIS
# 6           6     BISHOPSCOURT
# 7           7         BLOMTUIN
# 8           8      BONTEHEUWEL
# 9           9         BOTHASIG
#
#    Number of single-residential properties_number  Oct 2017\nkl/month  \
# 0                                            2272                  11
# 1                                             426                  10
# 2                                             248                  13
# 3                                            2041                  11
# 4                                            1488                   8
# 5                                            3746                   9
# 6                                             538                  12
# 7                                             201                   9
# 8                                            7098                   9
# 9                                            3399                   9
#
#      Month  Year   Latitude  Longitude
# 0  October  2017 -33.967220  18.502140
# 1  October  2017 -32.705958  18.485135
# 2  October  2017 -33.927953  18.382592
# 3  October  2017 -33.920011  18.642819
# 4  October  2017 -34.047464  18.452499
# 5  October  2017 -33.947283  18.575133
# 6  October  2017 -33.991092  18.444217
# 7  October  2017 -33.882677  18.652075
# 8  October  2017 -33.950161  18.554446
# 9  October  2017 -33.860418  18.544612

# %%
cpmap = folium.Map(location=[-33.967,18.485], zoom_start=10)

# %%
dataset.columns
# Out:
# Index(['Unnamed: 0', 'Suburb',
#        'Number of single-residential properties_number', 'Oct 2017\nkl/month',
#        'Month', 'Year', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
dataset['Oct 2017\nkl/month'][0]
# Out:
# 11

# %%
dataset['Suburb'][0]
# Out:
# 'ATHLONE'

# %%
place = dataset[ ['Latitude', 'Longitude'] ]

# %%
type(place)
# Out:
# pandas.core.frame.DataFrame

# %%
# dataframe : numpy array : python list
place = place.values.tolist()

# %%
type(place)
# Out:
# list

# %%
def Mapper(i,color):
    folium.Marker(
            location=point, 
            popup=dataset['Suburb'][i],
            icon=folium.Icon(color=color, icon='tint', icon_color='white' )
        ).add_to(cpmap)

# %%
i=0
for point in place:
    if dataset['Oct 2017\nkl/month'][i] >= 10:
        lw(i,'red')
    else:
        lw(i,'green')
    i+=1

# %%
cpmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
cpmap.save('mymap.html')
